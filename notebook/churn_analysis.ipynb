# %% [markdown]
# # Identifying Drivers of Customer Churn and Revenue Impact in a Telecom Company

# %% [markdown]
# ## 1. Executive Summary
#
# Customer churn represents a major challenge for subscription-based businesses because losing customers directly impacts recurring revenue. This analysis investigates customer churn patterns within a telecommunications dataset to identify factors associated with customer attrition and highlight potential strategies for improving customer retention.
#
# The dataset contains information on customer demographics, service subscriptions, billing behavior, and churn status. After cleaning and preparing the data, key performance indicators were calculated to assess the scale of churn within the customer base. Approximately 26–27% of customers in the dataset have churned, representing a significant proportion of the total customer base.
#
# Exploratory data analysis revealed several factors strongly associated with churn. Customers on month-to-month contracts exhibit substantially higher churn compared to customers on longer-term contracts. Additionally, churn is concentrated among customers with shorter tenure, indicating that many customers leave during the early stages of their relationship with the company.
#
# The analysis also suggests that customers with higher monthly charges tend to churn slightly more often, while fiber optic internet users exhibit higher churn levels compared to DSL users and customers without internet service. Furthermore, customers paying through electronic checks show noticeably higher churn compared to customers using automated payment methods such as credit cards or bank transfers.
#
# These findings suggest several opportunities for reducing churn, including encouraging customers to adopt longer-term contracts, improving onboarding and early customer engagement, promoting automated billing methods, and evaluating the customer experience associated with premium service plans.
#
# Overall, this analysis provides actionable insights that can support data-driven strategies for improving customer retention and reducing customer attrition.

# %% [markdown]
# ## 2. Business Context
# The telecommunications industry is highly competitive, with customers frequently switching providers due to pricing, service quality, or contract flexibility. Customer acquisition costs are significant, making retention critical for maintaining stable revenue growth. Recently, the company has observed an increase in customer attrition, prompting the need for a structured analysis to understand the underlying drivers of churn and identify actionable retention strategies.

# %% [markdown]
# ## 3. Problem Statement
# Although churn has been identified as a growing concern, the company does not yet have a detailed understanding of the customer characteristics and service features associated with customer attrition. Without this understanding, it is difficult to design effective retention strategies.
#
# The objective of this project is to analyze customer data to measure churn levels, investigate patterns across customer segments, and identify the primary factors influencing churn. The analysis will also estimate the financial impact of churn and suggest actionable measures for improving customer retention.

# %% [markdown]
# ## 4. KPI Definitions
#
# To evaluate customer churn and its business impact, the following Key Performance Indicators (KPIs) are defined for this analysis.
#
# These KPIs provide a structured way to measure customer attrition, identify high-risk segments, and estimate the financial impact of churn.

# %% [markdown]
# ### 4.1 Churn Rate (Primary KPI)
#
# **Definition:**
# Churn rate represents the percentage of customers who have discontinued their service during the observed period.
#
# **Calculation:**
#
# $$
# \text{Churn Rate} =
# \frac{\text{Number of Churned Customers}}
# {\text{Total Customers}} \times 100
# $$
#
# **Business Importance:**
# Churn rate is the primary indicator of customer retention. A high churn rate suggests customer dissatisfaction and directly impacts recurring revenue.

# %% [markdown]
# ### 4.2 Total Customers
#
# **Definition:**
# Total number of customers included in the dataset.
#
# **Calculation:**
#
# $$
# \text{Total Customers} = \text{Total Number of Records}
# $$
#
# **Business Importance:**
# This KPI represents the size of the customer base and provides context for interpreting churn levels.

# %% [markdown]
# ### 4.3 Total Churned Customers
#
# **Definition:**
# Total number of customers who have discontinued service.
#
# **Calculation:**
#
# $$
# \text{Total Churned Customers} =
# \text{Count of Customers Where Churn = Yes}
# $$
#
# **Business Importance:**
# This KPI measures the absolute scale of customer attrition and complements churn rate analysis.

# %% [markdown]
# ### 4.4 Revenue Lost Due to Churn
#
# **Definition:**
# Estimated monthly revenue associated with customers who have churned.
#
# **Calculation:**
#
# $$
# \text{Revenue Lost} =
# \sum(\text{Monthly Charges of Churned Customers})
# $$
#
# **Business Importance:**
# This KPI estimates the financial impact of customer churn and helps quantify the potential benefits of retention strategies.

# %% [markdown]
# ### 4.5 Average Revenue Per Customer (ARPU)
#
# **Definition:**
# Average monthly revenue generated per customer.
#
# **Calculation:**
#
# $$
# \text{ARPU} =
# \frac{\text{Total Monthly Charges}}
# {\text{Total Customers}}
# $$
#
# **Business Importance:**
# ARPU provides insight into customer value and helps identify whether high-value customers are more likely to churn.

# %% [markdown]
# ### 4.6 Average Tenure of Churned Customers
#
# **Definition:**
# Average duration of service for customers who have churned.
#
# **Calculation:**
#
# $$
# \text{Average Tenure (Churned)} =
# \text{Mean Tenure of Churned Customers}
# $$
#
# **Business Importance:**
# This KPI helps identify whether customers tend to leave early or after long-term usage, which is important for designing retention strategies.

# %% [markdown]
# ### 4.7 Segment-Level Churn Rate
#
# **Definition:**
# Churn rate calculated separately for different customer segments such as contract type, payment method, or tenure group.
#
# **Calculation Example:**
#
# $$
# \text{Segment Churn Rate} =
# \frac{\text{Churned Customers in Segment}}
# {\text{Total Customers in Segment}} \times 100
# $$
#
# **Business Importance:**
# Segment-level churn rates help identify high-risk customer groups and enable targeted retention strategies.

# %% [markdown]
# ## 5. Data Overview

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")

plt.rcParams["figure.figsize"] = (8,5)
plt.rcParams["axes.titlesize"] = 14
plt.rcParams["axes.labelsize"] = 12

# %%
import pandas as pd
df = pd.read_csv("data/telco_customer_churn.csv") # Loading Dataset

# %% [markdown]
# ### 5.1 Dataset Size
# The dataset contains 7,043 customer records and 21 variables.
# Each row represents an individual customer.

# %%
df.shape

# %% [markdown]
# ### 5.2 Sample Records
#
# The table below shows the first few records in the dataset.
# Each row corresponds to a unique customer and includes demographic information, service details, billing information, and churn status.

# %%
df.head()

# %% [markdown]
# ### 5.3 Variables in the Dataset
#
# The dataset includes variables related to:
#
# - Customer demographics
# - Account information
# - Services subscribed
# - Billing details
# - Churn status

# %%
df.columns # All the columns of the dataset

# %% [markdown]
# ### 5.4 Data Types
#
# The dataset contains a mixture of:
#
# - Numerical variables (e.g., tenure, monthly charges)
# - Categorical variables (e.g., contract type, payment method)
# - Binary variables (e.g., churn status)
#
# Understanding data types is important for ensuring accurate analysis.

# %%
df.info() # Number of values and their datatype corresponding to each column

# %% [markdown]
# ### 5.5 Target Variable Distribution
#
# The target variable in this analysis is **Churn**, which indicates whether a customer has discontinued service.
#
# The dataset contains both churned and non-churned customers, allowing for meaningful comparison between the two groups.

# %%
df['Churn'].value_counts()

# %%
df['Churn'].value_counts(normalize=True)*100 # Converting the above findings to a percentage value

# %% [markdown]
# ### 5.6 Summary Statistics
#
# The numerical variables include tenure, monthly charges, and total charges.
# Summary statistics provide an overview of their distributions and ranges.

# %%
df.describe()

# %% [markdown]
# ## 6. Data Cleaning

# %% [markdown]
# ### 6.1 Missing Values

# %% [markdown]
# The dataset was examined for missing values to ensure data completeness before analysis.
# The first step is to check for explicit missing values as done below.

# %%
df.isnull().sum() # Check for explicit missing values

# %% [markdown]
# No explicit missing value have been detected.
#
# However, missing values can hide in the form of blank strings, or strings like "NaN", "Null", etc.

# %% [markdown]
# The **TotalCharges** column which is tenure(numeric) multiplied by MonthlyCharges(numeric) is of the string data type, when it should be of the type float(numeric).
#
# The column was therefore tested for hidden missing values by attempting conversion to numeric format.

# %%
pd.to_numeric(df['TotalCharges'], errors='coerce').isnull().sum()

# %% [markdown]
# The conversion revealed 11 invalid entries in the **TotalCharges** column. These values could not be converted to numbers and were interpreted as missing values.
#
# These entries were originally stored as blank strings, which prevented them from being detected during the initial missing value check.

# %% [markdown]
# Since the missing values represent less than 0.2% (11/7043) of the dataset, removing these records is unlikely to affect the overall analysis.
#
# Therefore, rows containing missing values in the TotalCharges column were removed.

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce') # Converting from string to numeric

# %%
df = df.dropna(subset=['TotalCharges']) # Dropping missing values

# %%
df.isnull().sum() # Rechecking for missing values after alteration

# %% [markdown]
# Now that we have resolved the issue that occurred with the TotalCharges column, we can move forward with checking whether the other string-value columns have missing values as well or not.

# %%
(df.select_dtypes(include='str')
 .apply(lambda x: x.str.strip() == '')
 .sum())

# %%
for col in df.select_dtypes(include='str').columns:
    print(col, df[col].unique())

# %% [markdown]
# No missing values have been found.

# %% [markdown]
# ### 6.2 Data Type Validation
#
# The dataset contains both numerical and categorical variables.
#
# Numerical variables include tenure, MonthlyCharges, and TotalCharges.
# The TotalCharges column was converted to numeric format during the missing value investigation.
# All numerical variables were verified to have appropriate numeric data types.
#
# Categorical variables were stored as string types and represent customer demographics, service subscriptions, and billing characteristics. No further type adjustments were required.

# %%
df.info()

# %% [markdown]
# ### 6.3 Duplicate Records

# %%
df.duplicated().sum() # Duplicate records check

# %%
df['customerID'].duplicated().sum() # Duplicate IDs check

# %%
df['customerID'].nunique(), len(df) # Integrity of IDs check

# %% [markdown]
# No duplicate records were found in the dataset.
#
# Additionally, the customerID column was verified to contain unique values, confirming that each row represents a distinct customer.

# %% [markdown]
# ### 6.4 Data Sanity Check
#
# To ensure data reliability, numerical variables were examined for logically impossible or unrealistic values.

# %%
(df['tenure'] < 0).sum() # Checking for invalid tenure values

# %%
(df['MonthlyCharges'] < 0).sum() # Checking for invalid MonthlyCharges values

# %%
(df['TotalCharges'] < 0).sum() # Checking for invalid TotalCharges values

# %% [markdown]
# Next is to check for entries that have a tenure of 0 and have a corresponding TotalCharges value other than zero, which would be invalid.

# %%
df[df['tenure'] == 0][['tenure', 'TotalCharges']].head()

# %% [markdown]
# Checking how accurate the TotalCharges values are as compared to their corresponding tenure and MonthlyCharges values.

# %%
expected_total = df['tenure'] * df['MonthlyCharges']

plt.figure(figsize=(7,5))

plt.hexbin(
    expected_total,
    df['TotalCharges'],
    gridsize=50,
    cmap='Blues'
)

plt.colorbar(label="Number of Customers")

plt.xlabel("Expected Total Charges")
plt.ylabel("Actual Total Charges")
plt.title("Expected vs Actual Total Charges Density")

plt.show()

# %% [markdown]
# While TotalCharges should generally increase with tenure and monthly charges, deviations from the simple product relationship are expected due to partial billing cycles, discounts, or other billing adjustments. The dataset shows no systematic inconsistencies, and the relationship between these variables remains broadly consistent.

# %% [markdown]
# ## 7. KPI Calculation

# %% [markdown]
# Key Performance Indicators (KPIs) were calculated to quantify the scale of customer churn and evaluate its financial impact.
#
# These metrics provide a high-level overview of customer retention, revenue exposure, and customer behavior.

# %%
total_customers = len(df)

churned_customers = (df['Churn'] == 'Yes').sum()

churn_rate = churned_customers / total_customers * 100

revenue_lost = df[df['Churn'] == 'Yes']['MonthlyCharges'].sum()

arpu = df['MonthlyCharges'].mean()

avg_churn_tenure = df[df['Churn'] == 'Yes']['tenure'].mean()

# %%
churn_rate = round(churn_rate, 2)
revenue_lost = round(revenue_lost, 2)
arpu = round(arpu, 2)
avg_churn_tenure = round(avg_churn_tenure, 2)

# %%
kpi_table = pd.DataFrame({
    "KPI": [
        "Total Customers",
        "Total Churned Customers",
        "Churn Rate (%)",
        "Revenue Lost (Monthly)",
        "Average Revenue Per Customer (ARPU)",
        "Average Tenure of Churned Customers"
    ],
    "Value": [
        total_customers,
        churned_customers,
        churn_rate,
        revenue_lost,
        arpu,
        avg_churn_tenure
    ]
})
kpi_table

# %% [markdown]
# ## 8. Exploratory Data Analysis

# %% [markdown]
# ### 8.1 Churn Distribution
# The first step in the exploratory analysis is to examine the overall distribution of churn within the dataset.

# %%
churn_counts = df['Churn'].value_counts()

plt.figure(figsize=(6,6))

plt.pie(
    churn_counts,
    labels=churn_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=['skyblue', 'salmon'],
    explode=[0, 0.1]
)

plt.title("Customer Churn Distribution")

plt.show()

# %% [markdown]
# The distribution indicates that while the majority of customers remain with the company, approximately one quarter of the customer base has churned.
#
# Although retained customers still represent the larger group, a churn rate of around 26–27% represents a substantial loss of recurring revenue for a subscription-based business.
#
# This highlights the importance of identifying the factors associated with churn in order to improve customer retention and long-term revenue stability.

# %% [markdown]
# ### 8.2 Churn by Contract Type
# Contract structure can significantly influence customer retention. Customers on month-to-month contracts have greater flexibility to leave compared to those on longer-term agreements.
#
# This analysis examines how churn varies across different contract types.

# %%
import seaborn as sns
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x='Contract',
    hue='Churn',
    palette=['#87CEEB','#FA8072']
)

plt.title("Customer Churn by Contract Type")
plt.xlabel("Contract Type")
plt.ylabel("Number of Customers")

plt.show()

# %%
contract_churn_rate = (
    df.groupby('Contract')['Churn']
    .value_counts(normalize=True)
    .unstack()
)

contract_churn_rate['Yes'].plot(kind='bar', color='salmon')

plt.title("Churn Rate by Contract Type")
plt.xlabel("Contract Type")
plt.ylabel("Churn Rate")

plt.show()

# %% [markdown]
# ### 8.3 Churn by Customer Tenure
# Customer tenure represents the length of time a customer has remained with the company.
#
# Analyzing churn patterns across tenure helps determine whether customers are more likely to leave early in their lifecycle or after long-term usage.

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    data=df,
    x='tenure',
    hue='Churn',
    bins=30,
    multiple='stack',
    palette=['#87CEEB','#FA8072']
)

plt.title("Customer Tenure Distribution by Churn Status")
plt.xlabel("Tenure (Months)")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# The tenure distribution indicates that churn occurs predominantly among customers with shorter tenure.
#
# A large proportion of churned customers have been with the company for relatively few months, suggesting that early-stage customer retention may be a key challenge.
#
# Customers with longer tenure appear significantly less likely to churn, indicating that loyalty increases as customers remain with the service over time.

# %% [markdown]
# **Observation**
#
# Customers with shorter tenure exhibit significantly higher churn compared to long-term customers.
#
# **Implication**
#
# This suggests that the early stages of the customer lifecycle represent the highest churn risk.
# Improving onboarding experience and early engagement may help improve retention.

# %% [markdown]
# ### 8.4 Churn by Monthly Charges
# MonthlyCharges represents the amount billed to customers each month.
#
# Analyzing churn patterns across different pricing levels helps determine whether customers paying higher monthly fees are more likely to leave the service.

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    x='Churn',
    y='MonthlyCharges',
    color = 'skyblue'
)

plt.title("Monthly Charges Distribution by Churn Status")
plt.xlabel("Churn")
plt.ylabel("Monthly Charges")

plt.show()

# %% [markdown]
# The distribution indicates that customers who churn tend to have slightly higher monthly charges compared to those who remain with the company.
#
# This suggests that higher pricing may contribute to increased churn risk, potentially due to perceived cost relative to value.
#
# However, the overlap between the two distributions indicates that pricing alone does not fully explain churn behavior and should be considered alongside other factors such as contract type and tenure.

# %% [markdown]
# ### 8.5 Churn by Internet Service Type
# Customers in the dataset subscribe to different types of internet services, including DSL, fiber optic, or no internet service.
#
# Analyzing churn across these service categories helps determine whether certain service types are associated with higher customer attrition.

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x='InternetService',
    hue='Churn',
    palette=['#87CEEB','#FA8072']
)

plt.title("Customer Churn by Internet Service Type")
plt.xlabel("Internet Service Type")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# The analysis shows that churn rates vary significantly across different internet service types.
#
# Customers using fiber optic internet exhibit noticeably higher churn compared to DSL users and customers without internet service.
#
# This suggests that customers subscribing to fiber optic services may experience dissatisfaction related to pricing, service quality, or expectations associated with premium offerings.

# %% [markdown]
# ### 8.6 Churn by Payment Method
# Payment method may influence customer retention due to differences in convenience and payment automation.
#
# Customers who rely on automatic payment methods may be less likely to churn compared to those who manually process payments.

# %%
plt.figure(figsize=(9,5))

sns.countplot(
    data=df,
    x='PaymentMethod',
    hue='Churn',
    palette=['#87CEEB','#FA8072']
)

plt.title("Customer Churn by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("Number of Customers")

plt.xticks(rotation=20)

plt.show()

# %% [markdown]
# The analysis reveals noticeable differences in churn behavior across payment methods.
#
# Customers using electronic checks exhibit the highest churn levels, while those using automatic payment methods such as bank transfers or credit cards show significantly lower churn.
#
# This pattern suggests that customers who rely on manual payment processes may be less committed or more likely to discontinue service compared to those using automated billing methods.

# %% [markdown]
# ## 9. Key Insights
# The exploratory analysis identified several patterns associated with customer churn in the dataset. These insights highlight the factors most strongly related to customer attrition.

# %% [markdown]
# ### 9.1 Contract Type Is the Strongest Predictor of Churn
#
# Customers on month-to-month contracts exhibit significantly higher churn compared to customers with one-year or two-year contracts. Long-term contracts appear to promote customer retention, likely because they create a stronger commitment and reduce the ease with which customers can leave the service.
#
# ### 9.2 Churn Is Concentrated Among Customers with Short Tenure
#
# Customers with shorter tenure are considerably more likely to churn. The distribution of tenure indicates that many customers leave during the early stages of their relationship with the company. In contrast, customers who remain with the service for longer periods are much less likely to discontinue their subscription.
#
# ### 9.3 Higher Monthly Charges Are Slightly Associated with Churn
#
# Customers who churn tend to have slightly higher monthly charges than those who remain with the service. Although the distributions overlap significantly, this pattern suggests that pricing may influence customer decisions, particularly when customers perceive the cost to be higher relative to the value received.
#
# ### 9.4 Fiber Optic Internet Customers Exhibit Higher Churn
#
# Customers subscribing to fiber optic internet services show noticeably higher churn compared to DSL users and customers without internet service. This may indicate dissatisfaction related to service expectations, pricing, or perceived value associated with premium offerings.
#
# ### 9.5 Payment Method Is Associated with Retention Behavior
#
# Customers who pay using electronic checks display substantially higher churn compared to customers who use automatic payment methods such as credit card or bank transfer. This suggests that automated billing methods may be associated with greater customer commitment and convenience, which may reduce churn risk.
#
# Overall, the analysis indicates that contract structure, customer tenure, pricing, internet service type, and payment behavior are key factors associated with customer churn. These findings provide useful guidance for identifying high-risk customer segments and designing targeted retention strategies.

# %% [markdown]
# ## 10. Business Recommendations
# Based on the insights derived from the analysis, several strategies may help reduce customer churn and improve customer retention.

# %% [markdown]
# ### 10.1 Encourage Long-Term Contracts
#
# Since churn is significantly higher among customers on month-to-month contracts, the company could encourage customers to transition to longer-term agreements. Offering incentives such as discounts, bundled services, or loyalty benefits for one-year or two-year contracts may help improve retention.
#
# ### 10.2 Improve Early Customer Engagement
#
# Churn is concentrated among customers with shorter tenure, indicating that the early stages of the customer lifecycle are critical. Improving onboarding experiences, providing early customer support, and offering introductory incentives may help reduce early-stage churn.
#
# ### 10.3 Reevaluate Pricing and Value Communication
#
# Customers with higher monthly charges show slightly higher churn tendencies. The company may benefit from reassessing pricing strategies or improving the communication of value provided by higher-tier plans to ensure customers perceive sufficient value for the cost.
#
# ### 10.4 Investigate Fiber Optic Customer Experience
#
# Fiber optic customers exhibit higher churn compared to other service types. Further investigation into service quality, pricing structure, or customer expectations for fiber optic plans may help identify areas for improvement.
#
# ### 10.5 Promote Automatic Payment Methods
#
# Customers using electronic checks display higher churn rates compared to customers using automatic payment methods. Encouraging customers to adopt automated billing through credit cards or bank transfers may improve retention and reduce churn risk.

# %% [markdown]
# ## 11. Limitations
#
# This analysis identifies patterns associated with churn but does not establish causal relationships. Additionally, the dataset does not include variables such as customer satisfaction, service quality metrics, or competitor pricing, which may also influence churn behavior.
#
# Future analysis could incorporate additional data sources or predictive modeling approaches to better estimate churn risk.

# %% [markdown]
# ## 12. Conclusion
# This analysis explored customer churn patterns within the telecommunications dataset to identify factors associated with customer attrition.
#
# The results show that approximately 26–27% of customers have churned, indicating a substantial level of customer loss that can significantly impact recurring revenue. Exploratory analysis revealed that churn is strongly associated with several key factors, including contract type, customer tenure, internet service type, payment method, and monthly charges.
#
# Customers on month-to-month contracts and those with shorter tenure exhibit the highest churn levels, suggesting that early-stage customer engagement and contract structure play an important role in retention. Additionally, customers using fiber optic internet services and those paying through electronic checks show higher churn tendencies compared to other groups.
#
# These findings suggest that strategies focused on encouraging longer-term contracts, improving early customer engagement, promoting automated billing methods, and evaluating the customer experience for premium services could help reduce churn and improve long-term customer retention.
#
# Overall, the analysis provides valuable insights that can support data-driven decision-making for improving customer retention strategies.
